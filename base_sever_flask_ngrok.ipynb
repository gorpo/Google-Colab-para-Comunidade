# %% [markdown]
# # Servidor Web Python | Flask + Ngrok

# %% [markdown]
# Primeiramente execute a celula abaixo para instalar o pyngrok ele nos dará um link externo.

# %%
# !pip install  pyngrok

# %% [markdown]
# Agora vamos executar esta celula para instalar o Flask

# %%
# !pip install flask

# %% [markdown]
# Codigo base do Flask

# %%
from pyngrok import ngrok
from flask import Flask

#inicia uma instancia do flask
app = Flask(__name__)

#cria um link do ngrok na porta 5000
link_ngrok = ngrok.connect(5000)
print(f'Link compartilhavel: {link_ngrok}')


#cria uma pagina simples em html
@app.route("/")
def home():
    return "<h1>Meu primeiro site em Flask no Google Colab!</h1>"
  
app.run()
# Out:
# Link compartilhavel: http://ac3a58ba.ngrok.io
#  * Serving Flask app "__main__" (lazy loading)
#  * Environment: production
#    WARNING: This is a development server. Do not use it in a production deployment.
#    Use a production WSGI server instead.
#  * Debug mode: off
#  * Running on http://127.0.0.1:5000/ (Press CTRL+C to quit)
# 127.0.0.1 - - [19/May/2020 19:27:30] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [19/May/2020 19:27:30] "GET /favicon.ico HTTP/1.1" 404 -
