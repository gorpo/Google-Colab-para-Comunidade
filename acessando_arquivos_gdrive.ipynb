# %% [markdown]
# Acessando os arquivos do Google Drive

# %%
import os
from google.colab import drive

#montar o Gdrive
drive.mount('/content/gdrive/', force_remount= True)

# %%
# !ls "/content/gdrive/My Drive"
os.listdir("/content/gdrive/My Drive")

# %% [markdown]
# Criando uma pasta
# podemos usar comandos linux ou bash para criar diretorios e afins

# %%
# !mkdir "/content/gdrive/Shared drives/ManicomioPython/teste"

# %%
os.makedirs("/content/gdrive/Shared drives/ManicomioPython/teste1")
